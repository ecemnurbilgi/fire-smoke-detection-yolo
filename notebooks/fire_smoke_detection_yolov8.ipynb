# %%
# !pip install -q ultralytics
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 22.8 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from ultralytics import YOLO

print("YOLO imported successfully")
# Out:
# YOLO imported successfully

# %%
# !cp -r /content/drive/MyDrive/ada447_proje/data /content/data

# %%
yaml_content = """
path: /content/data

train: train/images
val: validation/images
test: test/images

names:
  0: smoke
  1: fire
"""

with open("/content/data.yaml", "w") as f:
    f.write(yaml_content)

print("Local data.yaml created")
# Out:
# Local data.yaml created

# %%
import torch

print("CUDA Available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

# %%
import os
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

results = model.train(
    data="/content/data.yaml",
    epochs=30,
    imgsz=640,
    batch=16,
    name="exp01_yolov8n_baseline",
    project="/content/drive/MyDrive/ada447_proje/runs",
    plots=False # Disable plotting during training to avoid font loading errors
)
# Out:
# Cleared matplotlib font cache: /root/.cache/matplotlib
# ...
# Ultralytics 8.4.60 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

results = model.train(
    data="/content/data.yaml",
    epochs=25,
    imgsz=640,
    batch=16,
    name="exp02_yolov8s_baseline",
    project="/content/drive/MyDrive/ada447_proje/runs"
)

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

results = model.train(
    data="/content/data.yaml",
    epochs=25,
    imgsz=640,
    batch=16,
    name="exp03_yolov8n_aug_off",
    project="/content/drive/MyDrive/ada447_proje/runs",

    # augmentation OFF
    mosaic=0.0,
    fliplr=0.0,
    flipud=0.0,
    hsv_h=0.0,
    hsv_s=0.0,
    hsv_v=0.0,
    translate=0.0,
    scale=0.0,
    shear=0.0,
    degrees=0.0,
    perspective=0.0,
    mixup=0.0,
    copy_paste=0.0,
    erasing=0.0
)

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.yaml")

results = model.train(
    data="/content/drive/MyDrive/ada447_proje/data.yaml",
    epochs=20,
    imgsz=640,
    batch=16,
    pretrained=False,
    name="exp04_yolov8n_scratch",
    project="/content/drive/MyDrive/ada447_proje/runs"
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.4.60 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# ...
